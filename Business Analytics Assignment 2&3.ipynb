# %%
import pandas as pd
df = pd.read_csv(r"D:\Pandas Tutorial\Task_Data.csv")
df
# Out:
#     ID   Team Country     NameF       NameL  Weight Height         DOB  \
# 0    1  Women  Canada    Meghan      Agosta   148.0    5'7   2/12/1987
# 1    2  Women  Canada   Rebecca    Johnston   148.0    5'9   9/24/1989
# 2    3  Women  Canada     Laura      Stacey   156.0   5'10    5/5/1994
# 3    4  Women  Canada  Jennifer   Wakefield   172.0   5'10   6/15/1989
# 4    5  Women  Canada   Jillian    Saulnier   144.0    5'5    3/7/1992
# ..  ..    ...     ...       ...         ...     ...    ...         ...
# 91  92    Men     USA      Ryan        Stoa   210.0    6'3   4/13/1987
# 92  93    Men     USA      Troy       Terry   179.0    6'0   9/10/1997
# 93  94    Men     USA      Noah       Welch   215.0    6'4   8/26/1982
# 94  95    Men     USA     James  Wisniewski   205.0    6'0   2/21/1984
# 95  96    Men     USA      Ryan    Zapolski   203.0    6'0  11/11/1986
#
#            Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# ...

# %% [markdown]
# **2.a) Fill na where DOB is Missing**

# %%
df.fillna({'DOB':'na'}, inplace=True)
df
# Out:
#     ID   Team Country     NameF       NameL  Weight Height         DOB  \
# 0    1  Women  Canada    Meghan      Agosta   148.0    5'7   2/12/1987
# 1    2  Women  Canada   Rebecca    Johnston   148.0    5'9   9/24/1989
# 2    3  Women  Canada     Laura      Stacey   156.0   5'10    5/5/1994
# 3    4  Women  Canada  Jennifer   Wakefield   172.0   5'10   6/15/1989
# 4    5  Women  Canada   Jillian    Saulnier   144.0    5'5    3/7/1992
# ..  ..    ...     ...       ...         ...     ...    ...         ...
# 91  92    Men     USA      Ryan        Stoa   210.0    6'3   4/13/1987
# 92  93    Men     USA      Troy       Terry   179.0    6'0   9/10/1997
# 93  94    Men     USA      Noah       Welch   215.0    6'4   8/26/1982
# 94  95    Men     USA     James  Wisniewski   205.0    6'0   2/21/1984
# 95  96    Men     USA      Ryan    Zapolski   203.0    6'0  11/11/1986
#
#            Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# ...

# %% [markdown]
# **2.b) Remove Row having No Weight of the player**

# %%
df.dropna(how="any", subset='Weight')
df
# Out:
#     ID   Team Country     NameF       NameL  Weight Height         DOB  \
# 0    1  Women  Canada    Meghan      Agosta   148.0    5'7   2/12/1987
# 1    2  Women  Canada   Rebecca    Johnston   148.0    5'9   9/24/1989
# 2    3  Women  Canada     Laura      Stacey   156.0   5'10    5/5/1994
# 3    4  Women  Canada  Jennifer   Wakefield   172.0   5'10   6/15/1989
# 4    5  Women  Canada   Jillian    Saulnier   144.0    5'5    3/7/1992
# ..  ..    ...     ...       ...         ...     ...    ...         ...
# 91  92    Men     USA      Ryan        Stoa   210.0    6'3   4/13/1987
# 92  93    Men     USA      Troy       Terry   179.0    6'0   9/10/1997
# 93  94    Men     USA      Noah       Welch   215.0    6'4   8/26/1982
# 94  95    Men     USA     James  Wisniewski   205.0    6'0   2/21/1984
# 95  96    Men     USA      Ryan    Zapolski   203.0    6'0  11/11/1986
#
#            Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# ...

# %% [markdown]
# **3.Group By Positions**

# %%
G = df.groupby('Pos')
G
for Pos, data in G:
    print("Pos:",Pos)
    print("\n")
    print("data:",data)
# Out:
# Pos: Defence
#
#
# data:     ID   Team Country       NameF        NameL  Weight Height         DOB  \
# 14  15  Women  Canada    Jocelyne     Larocque   139.0    5'6   5/19/1988
# 15  16  Women  Canada    Brigette    Lacquette   180.0    5'6  10/11/1992
# 16  17  Women  Canada    Lauriane      Rougeau   167.0    5'8   4/12/1990
# 17  18  Women  Canada       Laura      Fortino   137.0    5'4   1/30/1991
# 18  19  Women  Canada     Meaghan    Mikkelson   139.0    5'9    1/4/1985
# 19  20  Women  Canada      Renata         Fast   144.0    5'6   10/6/1994
# 37  38    Men  Canada        Karl     Stollery   181.0   5'11  11/21/1987
# 38  39    Men  Canada       Chris          Lee   187.0    6'0   10/3/1980
# 39  40    Men  Canada        Chay      Genoway   170.0    5'9  12/20/1986
# 40  41    Men  Canada  Marc-Andre     Gragnani   205.0    6'3   3/11/1987
# 41  42    Men  Canada      Stefan      Elliott   190.0    6'1   1/30/1991
# ...

# %% [markdown]
# **4. Median height of Male players and Mean weight of Female players**

# %%
M = df.groupby('Team')
M

# %%
M.get_group('Women')
Female_df = M.get_group('Women')
Female_df
# Out:
#     ID   Team Country         NameF               NameL  Weight Height  \
# 0    1  Women  Canada        Meghan              Agosta   148.0    5'7
# 1    2  Women  Canada       Rebecca            Johnston   148.0    5'9
# 2    3  Women  Canada         Laura              Stacey   156.0   5'10
# 3    4  Women  Canada      Jennifer           Wakefield   172.0   5'10
# 4    5  Women  Canada       Jillian            Saulnier   144.0    5'5
# 5    6  Women  Canada       Mélodie              Daoust   159.0    5'6
# 6    7  Women  Canada        Bailey                Bram   150.0    5'8
# 7    8  Women  Canada       Brianne              Jenner   156.0    5'9
# 8    9  Women  Canada         Sarah               Nurse   140.0    5'8
# 9   10  Women  Canada         Haley               Irwin   170.0    5'7
# 10  11  Women  Canada       Natalie             Spooner   180.0   5'10
# 11  12  Women  Canada         Emily               Clark   130.0    5'7
# ...

# %%
Female_df['Weight'].mean()
# Out:
# 151.38095238095238

# %%
Male_df=M.get_group('Men')
Male_df
# Out:
#     ID Team Country       NameF        NameL  Weight Height         DOB  \
# 23  24  Men  Canada     Gilbert        Brulé   190.0   5'11    1/1/1987
# 24  25  Men  Canada      Wojtek       Wolski   220.0    6'3   2/24/1986
# 25  26  Men  Canada       Derek          Roy   187.0    5'9    5/4/1983
# 26  27  Men  Canada       Chris        Kelly   194.0    6'0  11/11/1980
# 27  28  Men  Canada         Rob  Klinkhammer   214.0    6'3   8/12/1986
# 28  29  Men  Canada     Brandon        Kozun   170.0    5'8    3/8/1990
# 29  30  Men  Canada     Quinton       Howden   190.0    6'2   1/21/1992
# 30  31  Men  Canada        René      Bourque   216.0    6'2  12/10/1981
# 31  32  Men  Canada      Andrew       Ebbett   176.0    5'9    1/2/1983
# 32  33  Men  Canada       Mason      Raymond   179.0    6'1   9/17/1985
# 33  34  Men  Canada        Eric       O’Dell   201.0    6'1   6/21/1990
# 34  35  Men  Canada       Maxim     Lapierre   216.0    6'0   3/29/1985
# ...

# %%
Male_df['HtIn'].median()
# Out:
# 72.0

# %% [markdown]
# **5. Pivot Table**

# %%
df.pivot(index='ID', columns='Country')
# Out:
#           Team          NameF             NameL             Weight         \
# Country Canada  USA    Canada    USA     Canada         USA Canada    USA
# ID
# 1        Women  NaN    Meghan    NaN     Agosta         NaN  148.0    NaN
# 2        Women  NaN   Rebecca    NaN   Johnston         NaN  148.0    NaN
# 3        Women  NaN     Laura    NaN     Stacey         NaN  156.0    NaN
# 4        Women  NaN  Jennifer    NaN  Wakefield         NaN  172.0    NaN
# 5        Women  NaN   Jillian    NaN   Saulnier         NaN  144.0    NaN
# ..         ...  ...       ...    ...        ...         ...    ...    ...
# 92         NaN  Men       NaN   Ryan        NaN        Stoa    NaN  210.0
# 93         NaN  Men       NaN   Troy        NaN       Terry    NaN  179.0
# 94         NaN  Men       NaN   Noah        NaN       Welch    NaN  215.0
# 95         NaN  Men       NaN  James        NaN  Wisniewski    NaN  205.0
# 96         NaN  Men       NaN   Ryan        NaN    Zapolski    NaN  203.0
#
# ...

# %% [markdown]
# **5. Separate Male Canadian players and Female American players and then join the Sheets**

# %%
Gender = df.groupby('Team')
Gender

# %%
Male = Gender.get_group('Men')
Male
Female = Gender.get_group('Women')
Female
# Out:
#     ID   Team Country         NameF               NameL  Weight Height  \
# 0    1  Women  Canada        Meghan              Agosta   148.0    5'7
# 1    2  Women  Canada       Rebecca            Johnston   148.0    5'9
# 2    3  Women  Canada         Laura              Stacey   156.0   5'10
# 3    4  Women  Canada      Jennifer           Wakefield   172.0   5'10
# 4    5  Women  Canada       Jillian            Saulnier   144.0    5'5
# 5    6  Women  Canada       Mélodie              Daoust   159.0    5'6
# 6    7  Women  Canada        Bailey                Bram   150.0    5'8
# 7    8  Women  Canada       Brianne              Jenner   156.0    5'9
# 8    9  Women  Canada         Sarah               Nurse   140.0    5'8
# 9   10  Women  Canada         Haley               Irwin   170.0    5'7
# 10  11  Women  Canada       Natalie             Spooner   180.0   5'10
# 11  12  Women  Canada         Emily               Clark   130.0    5'7
# ...

# %%
Male[Male.Country=='Canada']
Canadian_Male = Male[Male.Country=='Canada']

Female[Female.Country=='USA']
American_Female = Female[Female.Country=='USA']

# %%
Merge = pd.concat([Canadian_Male, American_Female])
Merge.reset_index()
# Out:
#     index  ID   Team Country       NameF               NameL  Weight Height  \
# 0      23  24    Men  Canada     Gilbert               Brulé   190.0   5'11
# 1      24  25    Men  Canada      Wojtek              Wolski   220.0    6'3
# 2      25  26    Men  Canada       Derek                 Roy   187.0    5'9
# 3      26  27    Men  Canada       Chris               Kelly   194.0    6'0
# 4      27  28    Men  Canada         Rob         Klinkhammer   214.0    6'3
# 5      28  29    Men  Canada     Brandon               Kozun   170.0    5'8
# 6      29  30    Men  Canada     Quinton              Howden   190.0    6'2
# 7      30  31    Men  Canada        René             Bourque   216.0    6'2
# 8      31  32    Men  Canada      Andrew              Ebbett   176.0    5'9
# 9      32  33    Men  Canada       Mason             Raymond   179.0    6'1
# 10     33  34    Men  Canada        Eric              O’Dell   201.0    6'1
# ...

# %% [markdown]
# **Q.2 Use simple linear regression to predict CO2 emissions using volume and weight separately, plot their graphs and calculate the r values**
#
# **1) a. Using Volume**

# %%
import pandas as pd
df1 = pd.read_csv(r"D:\Pandas Tutorial\Regression_Data.csv")
df1
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyota        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
vol = df1['Volume']
X = vol.values
X
# Out:
# array([1000, 1200, 1000,  900, 1500, 1000, 1400, 1500, 1500, 1600, 1100,
#        1300, 1000, 1600, 1600, 1600, 1600, 2200, 1600, 2000, 1600, 2000,
#        2100, 1600, 2000, 1500, 2000, 2000, 1600, 2000, 2100, 2000, 1600,
#        1600, 1600, 2500], dtype=int64)

# %%
import matplotlib.pyplot as plt
from scipy import stats

X = df1['Volume']
y = df1['CO2']

slope, intercept, r, p, std_err = stats.linregress(X, y)

plt.scatter(X, y)
plt.show()

# %%
def myfunction(X):
    return slope*X + intercept

Model = list(map(myfunction, X))

# %%
plt.scatter(X, y)
plt.plot(X, Model)
plt.ylabel("CO2 Emission")
plt.xlabel("Volume")
# Out:
# Text(0.5, 0, 'Volume')

# %%
print(r)
# Out:
# 0.592081794691874

# %% [markdown]
# **b. Using Weight**

# %%
x = df1['Weight']
y = df1['CO2']

slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
model = list(map(myfunction, x))

# %%
plt.scatter(x,y)
plt.plot(x, model)
plt.ylabel("CO2 Emission")
plt.xlabel("Weight")
# Out:
# Text(0.5, 0, 'Weight')

# %%
print(r)
# Out:
# 0.5521500341348635

# %% [markdown]
# **2) Use multiple regression to predict CO2 emission using both weight and volume**

# %%
df1 = pd.read_csv(r"D:\Pandas Tutorial\Regression_Data.csv")

from sklearn import linear_model

# %%
a = df1[['Volume', 'Weight']]
b = df1['CO2']

# %%
regr = linear_model.LinearRegression()
regr.fit(a, b)
# Out:
# LinearRegression()

# %%
prediction = regr.predict([[3300, 1300]])
print(prediction)
# Out:
# [115.26830058]
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Q.3) Music Visualization**

# %%
import pandas as pd
df2 = pd.read_csv(r"D:\Pandas Tutorial\music_data")
df2
# Out:
#       length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0      66149          0.335406         0.091048  0.130405  0.003521
# 1      66149          0.343065         0.086147  0.112699  0.001450
# 2      66149          0.346815         0.092243  0.132003  0.004620
# 3      66149          0.363639         0.086856  0.132565  0.002448
# 4      66149          0.335579         0.088129  0.143289  0.001701
# ...      ...               ...              ...       ...       ...
# 9985   66149          0.349126         0.080515  0.050019  0.000097
# 9986   66149          0.372564         0.082626  0.057897  0.000088
# 9987   66149          0.347481         0.089019  0.052403  0.000701
# 9988   66149          0.387527         0.084815  0.066430  0.000320
# 9989   66149          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# ...

# %%
df2.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.380000e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130863e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# ...

# %%
df2.shape
# Out:
# (9990, 59)

# %%
import seaborn
seaborn.set(style='whitegrid')
seaborn.boxplot(x="label", y="tempo",data=df2)
# Out:
# <AxesSubplot:xlabel='label', ylabel='tempo'>

# %% [markdown]
# **Using Machine Learning to predict the genre by Logistic regression**

# %%
import numpy as np
from sklearn import linear_model

# %%
x1 = df2.iloc[:,:-1].values
y1 = df2.iloc[:,-1].values
y1
# Out:
# array(['blues', 'blues', 'blues', ..., 'rock', 'rock', 'rock'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.2, random_state = 0 )

# %%
#scalling
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x1_train = scale.fit_transform(x1_train)
x1_test = scale.transform(x1_test)

# %%
#Logistic Regression
from sklearn import linear_model 
logr = linear_model.LogisticRegression()
logr.fit(x1_train, y1_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#predict test results
y1_predicted = logr.predict(x1_test)

# %%
y1_predicted
# Out:
# array(['reggae', 'pop', 'rock', ..., 'jazz', 'metal', 'hiphop'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y1_predicted, y1_test)
# Out:
# 0.7307307307307307

# %% [markdown]
# **Thank You**
